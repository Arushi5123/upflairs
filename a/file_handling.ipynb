# %% [markdown]
# File handling

# %%
print('hello world')
# Out:
# hello world

# %%
file=open('hello.txt','r')
data=file.read()
print(data)
# Out:
# Hello we are from upflairs

# %%
file=open('hello.txt', 'w')
data=file.write("My name is Arushi Mathur")
print(data)
# Out:
# 24

# %%
file=open('hello.txt','a')
data=file.write("I am 20 years old")
print('\n',data)
# Out:
#  17

# %%
import os
os.listdir()
# Out:
# ['.vscode',
#  'arushi',
#  'as.py',
#  'atmsimulator.py',
#  'atmsimulator2.py',
#  'day2.py',
#  'day3',
#  'Day3.py',
#  'day4.py',
#  'day5.py',
#  'day6.py',
#  'day7.py',
#  'file_handling.ipynb',
#  'hello,txt',
#  'hello.txt',
#  'logic.py',
#  'solve.py',
#  '__pycache__']

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 6ED1-E534
#
#  Directory of c:\Users\DeLL\Desktop\a
#
# 14-06-2024  15:45    <DIR>          .
# 08-06-2024  16:36    <DIR>          ..
# 08-06-2024  16:54    <DIR>          .vscode
# 13-06-2024  11:52    <DIR>          __pycache__
# 11-06-2024  12:00    <DIR>          arushi
# 08-06-2024  16:37                 0 as.py
# 11-06-2024  23:45             2,461 atmsimulator.py
# 11-06-2024  13:00             1,707 atmsimulator2.py
# 08-06-2024  18:32             1,248 day2.py
# 10-06-2024  16:27    <DIR>          day3
# 10-06-2024  16:08             2,081 Day3.py
# 11-06-2024  10:58             1,319 day4.py
# 12-06-2024  15:35             4,093 day5.py
# 12-06-2024  17:51               937 day6.py
# 14-06-2024  15:35             1,607 day7.py
# 14-06-2024  16:43             1,923 file_handling.ipynb
# 14-06-2024  15:46               136 hello,txt
# 14-06-2024  15:48                43 hello.txt
# ...

# %%
import os
try:

  os.mkdir("arushi")
except FileExistsError :
    print("file already exist")
# Out:
# file already exist

# %%
try:
    os.rmdir("arushi")
except OSError:
    print("the file is not empty")
# Out:
# the file is not empty

# %%
os.makedirs('arushi',exist_ok=True)

# %%
file=open('hello.txt','r')
data=file.read(10)
print(data)
# Out:
# My name is

# %%
data=file.read(10)
print(data)
# Out:
#  Arushi Ma

# %%
file=open('demo2.txt','w')
message="hello we are student"
file.write(message)
file.close()

# %%
file=open('demo2.txt','w')
message="hello we are engineers"
file.write(message)
file.close()

# %%
file=open('demo2.txt','b')
message="\nhello we are engineers"
file.write(message)
file.close()

# %%
file=open('demo4.txt','w')
message="\n upflairs"
for i in range(1000):
        file.write(message)
file.close()

# %%
file=open('demo4.txt','r')
print(file.read())
file.close()
# Out:
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
# ...

# %%
with open('demo4.txt','r')as file:
    content =file.read()
    print(content)
# Out:
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
#  upflairs
# ...

# %%
with open('demo4.txt','r')as file:
    content =file.readlines()
    print(len(content))
# Out:
# 1000

# %%
pwd
# Out:
# 'c:\\Users\\DeLL\\Desktop\\a\\arushi'

# %%
os.chdir("c:\\Users\\DeLL\\Desktop\\a\\arushi")

# %%
os.chdir('arushi')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 os.chdir('arushi')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'arushi'

# %%
if os.path.exist("arushi"):
    print('yes present')
else:
    print("not present")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 if os.path.exist("arushi"):
#       2     print('yes present')
#       3 else:
#
# AttributeError: module 'ntpath' has no attribute 'exist'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 6ED1-E534
#
#  Directory of c:\Users\DeLL\Desktop\a\arushi
#
# 11-06-2024  12:00    <DIR>          .
# 14-06-2024  17:21    <DIR>          ..
# 11-06-2024  12:06                84 day1.html
#                1 File(s)             84 bytes
#                2 Dir(s)  73,546,366,976 bytes free

# %%
os.chdir("c:\\Users\\DeLL\\Desktop\\a")

# %%
pwd
# Out:
# 'c:\\Users\\DeLL\\Desktop\\a'

# %%
os.chdir('nikita')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 os.chdir('nikita')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'nikita'

# %%
if os.path.exists("nikita"):
    print("yes present")
else:
    os.mkdir("nikita")
# Out:
# yes present

# %%
cd ..
# Out:
# c:\Users\DeLL

# %%
cd Desktop
# Out:
# c:\Users\DeLL\Desktop
# C:\Users\DeLL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
cd a
# Out:
# [WinError 2] The system cannot find the file specified: 'a'
# c:\Users\DeLL\Desktop\a
# C:\Users\DeLL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
cd arushi
# Out:
# [WinError 2] The system cannot find the file specified: 'arushi'
# c:\Users\DeLL\Desktop\a\arushi
# C:\Users\DeLL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
path1=r"C:\Users\DeLL\Desktop"
path2="a"
complete_path= path1+"\\"+path2
print(complete_path)
# Out:
# C:\Users\DeLL\Desktop\a

# %%
import os
os.rmdir('nikita')

# %%
pwd
# Out:
# 'c:\\Users\\DeLL\\Desktop\\a'

# %%
os.mkdir("Assignment")

# %%
os.chdir('Assignment')

# %%
pwd
# Out:
# 'c:\\Users\\DeLL\\Desktop\\a\\Assignment'

# %%
os.mkdir('Quiz.py')

# %%
os.mkdir('Data')

# %%
os.mkdir('txt')

# %%
os.mkdir('image')

# %%
os.mkdir('pdf')

# %%
os.chdir('Data')

# %%
file=open('demo.txt','w')
file.write("Hello there")
file.close()

# %%
file=open('hello.txt','w')
file.write("hello there")
file.close()

# %%
import os
os.chdir("Assignment")

# %%
os.chdir('Data')

# %%
pwd
# Out:
# 'c:\\Users\\DeLL\\Desktop\\a\\Assignment\\Data'

# %%
import os 
import shutil as sh
for i in os.listdir(r'C:\Users\DeLL\Desktop\a\Assignment\Data'):
    if i.endswith(".txt"):
          sh.move(r'C:\Users\DeLL\Desktop\a\Assignment\Data'+'\\'+i,r'C:\Users\DeLL\Desktop\a\Assignment\txt'+'\\'+i)
    elif i.endswith(".jpg") or i.endswith(".jpeg") or i.endswith(".png"):
          sh.move(r'C:\Users\DeLL\Desktop\a\Assignment\Data'+'\\'+i,r'C:\Users\DeLL\Desktop\a\Assignment\image'+'\\'+i)
    elif i.endswith(".pdf"):
          sh.move(r'C:\Users\DeLL\Desktop\a\Assignment\Data'+'\\'+i,r'C:\Users\DeLL\Desktop\a\Assignment\pdf'+'\\'+i)
